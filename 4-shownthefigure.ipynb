# %%
import matplotlib.pyplot as plt

# Training history
accuracy = [0.6223, 0.9666, 0.9963, 0.9944, 0.9970, 0.9979, 0.9993, 0.9949]
loss = [2.4278, 0.0754, 0.0111, 0.0155, 0.0115, 0.0044, 0.0045, 0.0158]
val_accuracy = [0.9014, 0.9961, 0.9971, 0.9971, 1.0000, 1.0000, 0.9971, 0.9941]
val_loss = [0.1357, 0.0082, 0.0081, 0.0103, 0.0008, 0.0005, 0.0053, 0.0154]
epochs = range(1, len(accuracy) + 1)

# Plot accuracy
plt.plot(epochs, accuracy, 'r', label='Train Accuracy')
# Plot loss
plt.plot(epochs, loss, 'g', label='Train Loss')
# Plot validation accuracy
plt.plot(epochs, val_accuracy, 'b', label='Validation Accuracy')
# Plot validation loss
plt.plot(epochs, val_loss, 'k', label='Validation Loss')

plt.grid(True)
plt.xlabel('Epoch')
plt.ylabel('Accuracy / Loss')
plt.legend(loc='best')

# Save the figure
plt.savefig('training_results_vgg16.png', dpi=100)

plt.show()

# %%
import matplotlib.pyplot as plt

# Training history
loss = [0.6845, 0.1921, 0.1146, 0.0794, 0.0576, 0.0401, 0.0333, 0.0254, 0.0207, 0.0174, 0.0136, 0.0117, 0.0104, 0.0073, 0.0070, 0.0061, 0.0058, 0.0059, 0.0046, 0.0059, 0.0091, 0.0040, 0.0033, 0.0030, 0.0028]
accuracy = [0.7883, 0.9592, 0.9782, 0.9838, 0.9886, 0.9944, 0.9954, 0.9965, 0.9981, 0.9979, 0.9993, 0.9991, 0.9991, 1.0000, 0.9995, 1.0000, 0.9995, 0.9995, 1.0000, 0.9991, 0.9993, 1.0000, 1.0000, 1.0000, 1.0000]

val_loss = [1.9586, 1.8815, 1.8325, 1.7477, 1.5417, 1.2515, 0.8834, 0.5019, 0.2163, 0.0755, 0.0270, 0.0097, 0.0060, 0.0031, 0.0022, 0.0016, 0.0022, 0.0012, 0.0008, 0.0027, 0.0007, 0.0006, 0.0005, 0.0004, 0.0004]
val_accuracy = [0.0996, 0.2998, 0.3037, 0.3506, 0.3701, 0.4102, 0.5469, 0.9873, 0.9961, 0.9961, 0.9980, 1.0000, 0.9990, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000]
epochs = range(1, len(accuracy) + 1)

# Plot accuracy
plt.plot(epochs, accuracy, 'r', label='Train Accuracy')
# Plot loss
plt.plot(epochs, loss, 'g', label='Train Loss')
# Plot validation accuracy
plt.plot(epochs, val_accuracy, 'b', label='Validation Accuracy')
# Plot validation loss
plt.plot(epochs, val_loss, 'k', label='Validation Loss')

plt.grid(True)
plt.xlabel('Epoch')
plt.ylabel('Accuracy / Loss')
plt.legend(loc='best')

# Save the figure
plt.savefig('training_results_resnet50.png', dpi=300)

plt.show()

# %%
import matplotlib.pyplot as plt

# Training history
accuracy = [0.4489, 0.7948, 0.8996, 0.9548, 0.9689, 0.9812, 0.9831, 0.9870, 0.9914, 0.9937, 0.9928, 0.9947, 0.9965, 0.9974, 0.9974, 0.9981, 0.9968, 0.9970, 0.9984, 0.9993, 0.9998, 0.9986, 0.9981, 0.9991, 0.9998]
loss = [1.3664, 0.7327, 0.4660, 0.2952, 0.2152, 0.1439, 0.1243, 0.0984, 0.0719, 0.0614, 0.0495, 0.0454, 0.0341, 0.0304, 0.0269, 0.0225, 0.0215, 0.0207, 0.0166, 0.0160, 0.0129, 0.0148, 0.0139, 0.0117, 0.0104]
val_accuracy = [0.4619, 0.4805, 0.5000, 0.6729, 0.8857, 0.9648, 0.9873, 0.9912, 0.9941, 0.9980, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000]
val_loss = [1.6593, 1.4226, 1.1281, 0.7954, 0.4799, 0.2461, 0.1176, 0.0611, 0.0388, 0.0256, 0.0182, 0.0137, 0.0104, 0.0084, 0.0070, 0.0054, 0.0047, 0.0040, 0.0035, 0.0030, 0.0026, 0.0023, 0.0020, 0.0018, 0.0016]

epochs = range(1, len(accuracy) + 1)

# Plot accuracy
plt.plot(epochs, accuracy, 'r', label='Train Accuracy')
# Plot loss
plt.plot(epochs, loss, 'g', label='Train Loss')
# Plot validation accuracy
plt.plot(epochs, val_accuracy, 'b', label='Validation Accuracy')
# Plot validation loss
plt.plot(epochs, val_loss, 'k', label='Validation Loss')

plt.grid(True)
plt.xlabel('Epoch')
plt.ylabel('Accuracy / Loss')
plt.legend(loc='best')

# Save the figure
plt.savefig('training_results_inception.png', dpi=300)

plt.show()
